# %%
using Pkg
Pkg.activate(".")
Pkg.instantiate()
# Pkg.add("CUDA")
# Pkg.add("Glob")
# Pkg.add("Images")
# Pkg.add("FastAI")
# Pkg.add("FastVision")
# Pkg.add("Flux")
# Pkg.add("Metalhead")
# Pkg.add("Images")
# Pkg.add("DataAugmentation")
# Pkg.add("CairoMakie")
# Pkg.add("StaticArrays")
# Pkg.add("MLDataPattern")
# Out:
#   Activating project at `g:\桌面\2022 Fall\cs284A\Project`

# %%
using Glob
using CUDA
using FastAI
using FastVision
using MLDataPattern
using DataAugmentation, Images
using Flux
using Metalhead
using CairoMakie
using StaticArrays
using DICOM
using Images
using Printf
using NIfTI
using Base.Iterators
using Plots
CairoMakie.activate!(type="png")

# %% [markdown]
# # U-net for C1 -> C7 segmentation

# %% [markdown]
# Locate files with mask

# %%
mask_dir = raw"D:\RSNA-2022-dataset\segmentations"
train_image_dir = raw"G:\桌面\2022 Fall\cs284A\Project\Compressed_data\train_images"
# Out:
# "G:\\桌面\\2022 Fall\\cs284A\\Project\\Compressed_data\\train_images"

# %%
mask_names = []
for f in readdir(mask_dir, join=false)
    push!(mask_names, splitext(f)[1])
end

# %% [markdown]
# Check if we found all images with mask and load

# %%
matched_names = []
ct = 0
for img in readdir(train_image_dir, join=false)
    f = splitext(splitext(img)[1])[1]
    if f in mask_names
        push!(matched_names, f)
        ct += 1
    end
end
println("Found $ct of $(size(mask_names)[1])")
# Out:
# Found 87 of 87

# %% [markdown]
# Load images and mask

# %%
image_size = (128, 128, 128)
# Out:
# (128, 128, 128)

# %%
container_images = Array{Float32, 4}(undef, image_size..., ct)
container_masks = Array{Int64, 4}(undef, image_size..., ct);

# %% [markdown]
# Load 87 images from saved data.

# %%
Threads.@threads for i = 1 : 87
    curr_path = train_image_dir * "\\" * matched_names[i] * ".img.txt"
    temp = zeros(128, 128, 128)
    read!(curr_path, temp)
    container_images[:,:,:, i] = deepcopy(temp)
end

# %% [markdown]
# Load 87 masks from saved data.

# %%
Threads.@threads for i = 1 : 87
    curr_path = "G:\\桌面\\2022 Fall\\cs284A\\Project\\Compressed_data\\segmentations\\" * matched_names[i] * ".nii.txt"
    temp = zeros(128, 128, 128)
    read!(curr_path, temp)
    temp = reinterpret(Int64, temp)
    container_masks[:,:,:, i] = deepcopy(temp)
end

# %%
# i = 1
# Threads.@threads for i = 1 : size(matched_names)[1]
#     num_slices = size(readdir(train_image_dir * "\\" * matched_names[i]))[1]
#     curr_image = zeros(num_slices, 512, 512)
#     curr_mask = zeros(512, 512, num_slices)
#     # read image
#     curr_images_dcm_data_array = dcmdir_parse(train_image_dir * "\\" * matched_names[i])
#     for slice = 1 : num_slices
#         curr_image[slice, :, :] = curr_images_dcm_data_array[slice][(0x7fe0, 0x0010)]
#     end
#     curr_image = permutedims(curr_image, [3, 2, 1])
#     # read mask
#     curr_mask = niread(mask_dir * "\\" * matched_names[i] * ".nii")
#     curr_mask = reverse(curr_mask; dims = 2)
#     curr_mask = reverse(curr_mask; dims = 3)
#     curr_mask = replace(x -> x>7 ? 0 : x, curr_mask)
#     # Normalize
#     curr_max, curr_min = maximum(curr_image), minimum(curr_image)
#     curr_image = (curr_image .- curr_min) ./ (curr_max - curr_min);
#     # Resize 
#     container_images[:,:,:, i] = imresize(curr_image, image_size)
#     container_masks[:,:,:, i] = round.(imresize(curr_mask, image_size))
#     # println(i)
#     # flush(stdout)
# end

# %%
# # Normalize
# for i = 1 : 87
#     open("G:\\桌面\\2022 Fall\\cs284A\\Project\\train\\"* string(i) * ".img", "w") do file
#         write(file, string(container_images[:,:,:, i]))
#     end
#     # curr_img = container_images[:,:,:, i]
#     # curr_max, curr_min = maximum(curr_img), minimum(curr_img)
#     # curr_img = (curr_img .- curr_min) ./ (curr_max - curr_min)
#     # container_images[:,:,:, i] = curr_img
# end

# %%
# container_images = Float32.(container_images);

# %%
# container_masks = Int64.(container_masks .+ 1);

# %%
data = (container_images, container_masks);
# data = [(container_images[:,:,:,x], container_masks[:,:,:,x]) for x in 1:87];

# %%
maximum(container_images), minimum(container_images)
# Out:
# (1.0f0, 0.0f0)

# %%
maximum(container_masks), minimum(container_masks)
# Out:
# (8, 1)

# %%
image1, mask1 = sample = (container_images[:,:,:,1], container_masks[:,:,:,1]);

# %%
typeof(sample[1])
# Out:
# Array{Float32, 3}

# %%
typeof(sample[2])
# Out:
# Array{Int64, 3}

# %%
CairoMakie.heatmap(mask1[:, :, 60])
# Out:
# FigureAxisPlot()

# %%
CairoMakie.heatmap(image1[:, :, 60])
# Out:
# FigureAxisPlot()

# %%
data_mean, data_std = FastVision.imagedatasetstats(container_images, Gray{N0f8}) 
data_mean, data_std = StaticArraysCore.SVector{1, Float32}(data_mean[1]), StaticArraysCore.SVector{1, Float32}(data_std[1])
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:01
# (Float32[0.27950126], Float32[0.1629326])

# %% [markdown]
# Create a task

# %%
taskk = SupervisedTask(
    (FastVision.Image{3}(), Mask{3}(1:8)), # 7 classes and 1 background
    (
        FastVision.ProjectiveTransforms((image_size)),
        ImagePreprocessing(means = data_mean, stds = data_std, C = Gray{N0f8}),
        FastAI.OneHot()
    )
)
# Out:
# SupervisedTask(FastVision.Image{3} -> Mask{3, Int64})

# %%
checkblock(taskk.blocks.sample, sample)
# Out:
# true

# %%
train_files, val_files = MLDataPattern.splitobs(data, 0.8);

# %%
traindl, validdl = FastAI.taskdataloaders(train_files, val_files, taskk, 1);

# %% [markdown]
# Model

# %%
conv = (stride, in, out) -> Conv((3, 3, 3), in=>out, stride=stride, pad=(1, 1, 1))
tran = (stride, in, out) -> ConvTranspose((4, 4, 4), in=>out, stride=stride, pad=1)

conv1 = (in, out) -> Chain(conv(1, in, out), BatchNorm(out), x -> leakyrelu.(x))
conv2 = (in, out) -> Chain(conv(2, in, out), BatchNorm(out), x -> leakyrelu.(x))
tran2 = (in, out) -> Chain(tran(2, in, out), BatchNorm(out), x -> leakyrelu.(x))
# Out:
# #23 (generic function with 1 method)

# %%
function unet3D(in_chs, lbl_chs)
    # Contracting layers
    l1 = Chain(conv1(in_chs, 4))
    l2 = Chain(l1, conv1(4, 4), conv2(4, 16))
    l3 = Chain(l2, conv1(16, 16), conv2(16, 32))
    l4 = Chain(l3, conv1(32, 32), conv2(32, 64))
    l5 = Chain(l4, conv1(64, 64), conv2(64, 128))

    # Expanding layers
    l6 = Chain(l5, tran2(128, 64), conv1(64, 64))
    l7 = Chain(Parallel(+, l6, l4), tran2(64, 32), conv1(32, 32))       # Residual connection between l6 & l4
    l8 = Chain(Parallel(+, l7, l3), tran2(32, 16), conv1(16, 16))       # Residual connection between l7 & l3
    l9 = Chain(Parallel(+, l8, l2), tran2(16, 4), conv1(4, 4))          # Residual connection between l8 & l2
    l10 = Chain(l9, conv1(4, lbl_chs))
end
# Out:
# unet3D (generic function with 1 method)

# %%
# model = unet3D(1, 8) |> gpu;
taskk, model= loadtaskmodel("try2_stage1_5.jld2"); # continue train from prev saved model

# %% [markdown]
# Loss function

# %%
function _dice_kernel(f, x, y, l, thread_stride, j, b_max)
    index = threadIdx().x
	i = index + (blockIdx().x - 1i32) * thread_stride

    if i > l
		return
    end
	
    b_l = blockIdx().x == b_max ? l - (blockIdx().x - 1i32) * thread_stride : thread_stride
    cache = CuDynamicSharedArray(Float64, (thread_stride,))

	@inbounds cache[index] = x[i] * y[i]
		
    sync_threads()
    prev_mid = b_l
    while true
        mid = (prev_mid - 1i32) ÷ 2i32 + 1i32
        if index+mid <= prev_mid
            @inbounds cache[index] += cache[index+mid]
        end
        prev_mid = mid
        sync_threads()
        mid == 1i32 && break
    end
    
    if index == 1i32
        @inbounds CUDA.@atomic f[j] += cache[1]
    end
    return nothing
end
# Out:
# _dice_kernel (generic function with 1 method)

# %%
function dice(ŷ::CuArray, y::CuArray; ϵ=1e-5)
	f = CuArray([0.0, 0.0])
	l = length(ŷ)
	
	k = @cuda launch=false _dice_kernel(f, ŷ, y, l, 0, 0, 0)
    GPU_threads = launch_configuration(k.fun).threads
	t = min(l, GPU_threads)
    b= cld(l, t)
	
    k(f, ŷ, y, l, t, 1, b; threads=t, blocks=b, shmem=t*8)
	k(f, ŷ, ŷ, l, t, 2, b; threads=t, blocks=b, shmem=t*8)
	k(f, y, y, l, t, 2, b; threads=t, blocks=b, shmem=t*8)

    f = Array(f)
    @inbounds return 1 - muladd(2, f[1], ϵ) / (f[2] + ϵ)
end
# Out:
# dice (generic function with 2 methods)

# %%
lossfn = tasklossfn(taskk)
# Out:
# _segmentationloss (generic function with 1 method)

# %% [markdown]
# Training

# %%
optimizer = ADAM() 
learner = Learner(model, lossfn; data=(traindll, validdll), optimizer, callbacks=[ToGPU()])
# Out:
# Learner()

# %%
fitonecycle!(learner, 10, 0.033)
# Out:
# Epoch 1 TrainingPhase(): 100%|██████████████████████████| Time: 0:10:59
# Epoch 1 ValidationPhase(): 100%|████████████████████████| Time: 0:00:14
# Epoch 2 TrainingPhase(): 100%|██████████████████████████| Time: 0:00:41
# Epoch 2 ValidationPhase(): 100%|████████████████████████| Time: 0:00:08
# Epoch 3 TrainingPhase(): 100%|██████████████████████████| Time: 0:00:43
# Epoch 3 ValidationPhase(): 100%|████████████████████████| Time: 0:00:09
# Epoch 4 TrainingPhase(): 100%|██████████████████████████| Time: 0:00:45
# Epoch 4 ValidationPhase(): 100%|████████████████████████| Time: 0:00:09
# Epoch 5 TrainingPhase(): 100%|██████████████████████████| Time: 0:00:49
# Epoch 5 ValidationPhase(): 100%|████████████████████████| Time: 0:00:07
# Epoch 6 TrainingPhase(): 100%|██████████████████████████| Time: 0:00:36
# Epoch 6 ValidationPhase(): 100%|████████████████████████| Time: 0:00:05
# Epoch 7 TrainingPhase(): 100%|██████████████████████████| Time: 0:00:34
# ...

# %%
savetaskmodel("stage1_1.jld2", taskk, learner.model, force = true)

# %%
for i = 2:15
    fitonecycle!(learner, 10, 0.033)
    savetaskmodel("stage1_"*string(i)*".jld2", taskk, learner.model, force = true)
    println("$i saved.")
    flush(stdout)
end
# Out:
# Epoch 11 TrainingPhase(): 100%|█████████████████████████| Time: 0:00:42
# Epoch 11 ValidationPhase(): 100%|███████████████████████| Time: 0:00:07
# Epoch 12 TrainingPhase(): 100%|█████████████████████████| Time: 0:00:43
# Epoch 12 ValidationPhase(): 100%|███████████████████████| Time: 0:00:08
# Epoch 13 TrainingPhase(): 100%|█████████████████████████| Time: 0:00:41
# Epoch 13 ValidationPhase(): 100%|███████████████████████| Time: 0:00:09
# Epoch 14 TrainingPhase(): 100%|█████████████████████████| Time: 0:00:50
# Epoch 14 ValidationPhase(): 100%|███████████████████████| Time: 0:00:07
# Epoch 15 TrainingPhase(): 100%|█████████████████████████| Time: 0:00:35
# Epoch 15 ValidationPhase(): 100%|███████████████████████| Time: 0:00:08
# Epoch 16 TrainingPhase(): 100%|█████████████████████████| Time: 0:00:42
# Epoch 16 ValidationPhase(): 100%|███████████████████████| Time: 0:00:08
# Epoch 17 TrainingPhase(): 100%|█████████████████████████| Time: 0:00:35
# ...

# %% [markdown]
# Test outputs

# %%
task_trained, model_trained = loadtaskmodel("try2_stage1_5.jld2");

# %%
(sample1, sample2, sample3, sample4, sample5, sample6, sample7, sample8) = validdl;

# %% [markdown]
# ## Test case 1

# %%
pred1 = model_trained(sample1[1]);

# %% [markdown]
# ### direction = x

# %% [markdown]
# Original image 1

# %%
hmp = CairoMakie.heatmap(sample1[1][60, :, :])
save(".\\pred_figures\\1_x_1.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# Original mask 1

# %%
hmp = CairoMakie.heatmap(sample1[2][60, :, :, 5])
save(".\\pred_figures\\1_x_2_c5.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# Predict mask 1

# %%
hmp = CairoMakie.heatmap(pred1[60, :, :, 5])
save(".\\pred_figures\\1_x_3_c5.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# After filter

# %%
hmp = CairoMakie.heatmap(round.(pred1[60, :, :, 5]))
save(".\\pred_figures\\1_x_4_c5.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# ### direction = y

# %% [markdown]
# Original image 1

# %%
hmp = CairoMakie.heatmap(sample1[1][:, 50, :])
save(".\\pred_figures\\1_y_1.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# Original mask 1

# %%
hmp = CairoMakie.heatmap(sample1[2][:, 50, :, 6])
save(".\\pred_figures\\1_y_2_c6.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# Predict mask 1

# %%
hmp = CairoMakie.heatmap(pred1[:, 50, :, 6])
save(".\\pred_figures\\1_y_3_c6.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# After filter

# %%
hmp = CairoMakie.heatmap(round.(pred1[:, 50, :, 6]))
save(".\\pred_figures\\1_y_4_c6.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# ### direction = z

# %% [markdown]
# Original image 1

# %%
hmp = CairoMakie.heatmap(sample1[1][:, :, 50])
save(".\\pred_figures\\1_z_1.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# Original mask 1

# %%
hmp = CairoMakie.heatmap(sample1[2][:, :, 50, 3])
save(".\\pred_figures\\1_z_2_c3.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# Pred image 1

# %%
hmp = CairoMakie.heatmap(pred1[:, :, 50, 3])
save(".\\pred_figures\\1_z_3_c3.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# After filter

# %%
hmp = CairoMakie.heatmap(round.(pred1[:, :, 50, 3]))
save(".\\pred_figures\\1_z_4_c3.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# ## Test case 2

# %%
pred2 = model_trained(sample2[1]);

# %% [markdown]
# ### direction = x

# %% [markdown]
# Original image

# %%
hmp = CairoMakie.heatmap(sample2[1][60, :, :, 1, 1])
save(".\\pred_figures\\2_x_1.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# Original mask

# %%
hmp = CairoMakie.heatmap(sample2[2][60, :, :, 3, 1])
save(".\\pred_figures\\2_x_2_c3.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# Predicted mask

# %%
hmp = CairoMakie.heatmap(pred2[60, :, :, 3, 1])
save(".\\pred_figures\\2_x_3_c3.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# After filter

# %%
hmp = CairoMakie.heatmap(round.(pred2[60, :, :, 3, 1]))
save(".\\pred_figures\\2_x_4_c3.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# ### direction = y

# %% [markdown]
# Original image

# %%
hmp = CairoMakie.heatmap(sample2[1][:, 60, :, 1 ,1])
save(".\\pred_figures\\2_y_2.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# Original mask

# %%
hmp = CairoMakie.heatmap(sample2[2][:, 60, :, 5, 1])
save(".\\pred_figures\\2_y_2_c5.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# Predicted mask

# %%
hmp = CairoMakie.heatmap(pred2[:, 60, :, 5, 1])
save(".\\pred_figures\\2_y_3_c5.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# After filter

# %%
hmp = CairoMakie.heatmap(round.(pred2[:, 60, :, 5, 1]))
save(".\\pred_figures\\2_y_4_c5.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# ### direction = z

# %% [markdown]
# Original image

# %%
hmp = CairoMakie.heatmap(sample2[1][:, :, 60, 1, 1])
save(".\\pred_figures\\2_z_2.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# Original mask

# %%
hmp = CairoMakie.heatmap(sample2[2][:, :, 60, 5, 1])
save(".\\pred_figures\\2_z_2_c5.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# Predicted mask

# %%
hmp = CairoMakie.heatmap(pred2[:, :, 60, 5, 1])
save(".\\pred_figures\\2_z_3_c5.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# After filter

# %%
hmp = CairoMakie.heatmap(round.(pred2[:, :, 60, 5, 1]))
save(".\\pred_figures\\2_z_4_c5.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# ## Test case 3

# %%
pred3 = model_trained(sample3[1]);

# %% [markdown]
# ### direction = x

# %% [markdown]
# Original image

# %%
hmp = CairoMakie.heatmap(sample3[1][60, :, :, 1, 1])
save(".\\pred_figures\\3_x_1.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# Original mask

# %%
hmp = CairoMakie.heatmap(sample3[2][60, :, :, 4, 1])
save(".\\pred_figures\\3_x_2_c4.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# Predicted mask

# %%
hmp = CairoMakie.heatmap(pred3[60, :, :, 4, 1])
save(".\\pred_figures\\3_x_3_c4.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# After filter

# %%
hmp = CairoMakie.heatmap(round.(pred3[60, :, :, 4, 1]))
save(".\\pred_figures\\3_x_4_c4.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# ### direction = y

# %% [markdown]
# Original image

# %%
hmp = CairoMakie.heatmap(sample3[1][:, 60, :, 1, 1])
save(".\\pred_figures\\3_y_1.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# Original mask

# %%
hmp = CairoMakie.heatmap(sample3[2][:, 60, :, 2, 1])
save(".\\pred_figures\\3_y_2_c2.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# Predicted mask

# %%
hmp = CairoMakie.heatmap(pred3[:, 60, :, 2, 1])
save(".\\pred_figures\\3_y_3_c2.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# After filter

# %%
hmp = CairoMakie.heatmap(round.(pred3[:, 60, :, 2, 1]))
save(".\\pred_figures\\3_y_4_c2.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# ### direction = z

# %% [markdown]
# Original image

# %%
hmp = CairoMakie.heatmap(sample3[1][:, :, 60, 1, 1])
save(".\\pred_figures\\3_z_1.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# Original mask

# %%
hmp = CairoMakie.heatmap(sample3[2][:, :, 60, 2, 1])
save(".\\pred_figures\\3_z_2_c2.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# Predicted mask

# %%
hmp = CairoMakie.heatmap(pred2[:, :, 60, 2, 1])
save(".\\pred_figures\\3_z_3_c2.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# After filter

# %%
hmp = CairoMakie.heatmap(round.(pred2[:, :, 60, 2, 1]))
save(".\\pred_figures\\3_z_4_c2.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# ## Test case 4

# %%
pred4 = model_trained(sample4[1]);

# %% [markdown]
# ### direction = x

# %% [markdown]
# Original image

# %%
hmp = CairoMakie.heatmap(sample4[1][60, :, :, 1, 1])
save(".\\pred_figures\\4_x_1.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# Original mask

# %%
hmp = CairoMakie.heatmap(sample4[2][60, :, :, 6, 1])
save(".\\pred_figures\\4_x_2_c6.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# Predicted mask

# %%
hmp = CairoMakie.heatmap(pred4[60, :, :, 6, 1])
save(".\\pred_figures\\4_x_3_c6.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# After filter

# %%
hmp = CairoMakie.heatmap(round.(pred4[60, :, :, 6, 1]))
save(".\\pred_figures\\4_x_4_c6.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# ### direction = y

# %% [markdown]
# Original image

# %%
hmp = CairoMakie.heatmap(sample4[1][:, 60, :, 1, 1])
save(".\\pred_figures\\4_y_1.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# Original mask

# %%
hmp = CairoMakie.heatmap(sample4[2][:, 60, :, 5, 1])
save(".\\pred_figures\\4_y_2_c5.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# Predicted mask

# %%
hmp = CairoMakie.heatmap(pred4[:, 60, :, 5, 1])
save(".\\pred_figures\\4_y_3_c5.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# After filter

# %%
hmp = CairoMakie.heatmap(round.(pred4[:, 60, :, 5, 1]))
save(".\\pred_figures\\4_y_4_c5.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# ### direction = z

# %% [markdown]
# Original image

# %%
hmp = CairoMakie.heatmap(sample4[1][:, :, 40, 1, 1])
save(".\\pred_figures\\4_z_1.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# Original mask

# %%
hmp = CairoMakie.heatmap(sample4[2][:, :, 40, 3, 1])
save(".\\pred_figures\\4_z_2_c3.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# Predicted mask

# %%
hmp = CairoMakie.heatmap(pred4[:, :, 40, 3, 1])
save(".\\pred_figures\\4_z_3_c3.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# After filter

# %%
hmp = CairoMakie.heatmap(round.(pred4[:, :, 40, 3, 1]))
save(".\\pred_figures\\4_z_4_c3.png", hmp)
hmp
# Out:
# FigureAxisPlot()

# %% [markdown]
# ## Test case 5

# %% [markdown]
# ### direction = x

# %% [markdown]
# Original image

# %% [markdown]
# Original mask

# %% [markdown]
# Predicted mask

# %% [markdown]
# After filter

# %% [markdown]
# ### direction = y

# %% [markdown]
# Original image

# %% [markdown]
# Original mask

# %% [markdown]
# Predicted mask

# %% [markdown]
# After filter

# %% [markdown]
# ### direction = z

# %% [markdown]
# Original image

# %% [markdown]
# Original mask

# %% [markdown]
# Predicted mask

# %% [markdown]
# After filter

# %% [markdown]
# ## Test case 6

# %% [markdown]
# ### direction = x

# %% [markdown]
# Original image

# %% [markdown]
# Original mask

# %% [markdown]
# Predicted mask

# %% [markdown]
# After filter

# %% [markdown]
# ### direction = y

# %% [markdown]
# Original image

# %% [markdown]
# Original mask

# %% [markdown]
# Predicted mask

# %% [markdown]
# After filter

# %% [markdown]
# ### direction = z

# %% [markdown]
# Original image

# %% [markdown]
# Original mask

# %% [markdown]
# Predicted mask

# %% [markdown]
# After filter

# %% [markdown]
# ## Test case 7

# %% [markdown]
# ### direction = x

# %% [markdown]
# Original image

# %% [markdown]
# Original mask

# %% [markdown]
# Predicted mask

# %% [markdown]
# After filter

# %% [markdown]
# ### direction = y

# %% [markdown]
# Original image

# %% [markdown]
# Original mask

# %% [markdown]
# Predicted mask

# %% [markdown]
# After filter

# %% [markdown]
# ### direction = z

# %% [markdown]
# Original image

# %% [markdown]
# Original mask

# %% [markdown]
# Predicted mask

# %% [markdown]
# After filter

# %% [markdown]
# ## Test case 8

# %% [markdown]
# ### direction = x

# %% [markdown]
# Original image

# %% [markdown]
# Original mask

# %% [markdown]
# Predicted mask

# %% [markdown]
# After filter

# %% [markdown]
# ### direction = y

# %% [markdown]
# Original image

# %% [markdown]
# Original mask

# %% [markdown]
# Predicted mask

# %% [markdown]
# After filter

# %% [markdown]
# ### direction = z

# %% [markdown]
# Original image

# %% [markdown]
# Original mask

# %% [markdown]
# Predicted mask

# %% [markdown]
# After filter
